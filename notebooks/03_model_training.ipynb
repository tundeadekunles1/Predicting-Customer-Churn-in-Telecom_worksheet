# %%
import os 
import sys
#print("Initial cwd:", os.getcwd())
#Go up one level from notebooks/ to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Using project root:", project_root)

# 1. Imports (run this once at the top)
import os
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.model_training import prepare_data, train_logistic_regression, train_random_forest
from src.evaluation import evaluate_model
# 2. Load processed data and prepare splits
processed_path = os.path.join(project_root, "data", "processed", "telco_churn_processed.csv")
df = pd.read_csv(processed_path)

print("df shape:", df.shape)
X_train, X_test, y_train, y_test = prepare_data(df)
print("X_train:", X_train.shape, "X_test:", X_test.shape)

# 3. Train models (these cells have no output unless you print)
log_model = train_logistic_regression(X_train, y_train)
rf_model  = train_random_forest(X_train, y_train)

print("Log model type:", type(log_model))
print("RF model type:", type(rf_model))

# 4. Evaluate models
log_results = evaluate_model(log_model, X_test, y_test)
rf_results  = evaluate_model(rf_model,  X_test, y_test)

print("Logistic Regression accuracy:", log_results["accuracy"])
print("Random Forest accuracy:", rf_results["accuracy"])
# Out:
# Using project root: c:\Users\User\Predicting-Customer-Churn-in-Telecom
# df shape: (7043, 25)
# X_train: (5634, 22) X_test: (1409, 22)
# Log model type: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# RF model type: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Logistic Regression accuracy: 0.7991483321504613
# Random Forest accuracy: 0.7863733144073811
