# %%
import os 
import sys
import pandas as pd

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.feature_engineering import engineer_features
from src.data_preprocessing import load_data, clean_data

# %%
df = load_data("../data/processed/telco_cleaned.csv")

# generate new features
df = engineer_features(df)

# explore new features
df[['SeniorCitizen', 'tenure', 'tenure_group']].head()
df.info()

# Save dataset with new features for model training
df.to_csv("../data/processed/telco_churn_processed.csv", index=False)
print("Processed dataset saved to data/processed/")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   SeniorCitizen                          7043 non-null   int64
#  1   tenure                                 7043 non-null   int64
#  2   MonthlyCharges                         7043 non-null   float64
#  3   TotalCharges                           7043 non-null   float64
#  4   charges_ratio                          7043 non-null   float64
#  5   tenure_group                           7043 non-null   category
#  6   gender_Male                            7043 non-null   bool
#  7   Partner_Yes                            7043 non-null   bool
#  8   Dependents_Yes                         7043 non-null   bool
#  9   PhoneService_Yes                       7043 non-null   bool
#  10  MultipleLines_Yes                      7043 non-null   bool
#  11  InternetService_Fiber optic            7043 non-null   bool
#  12  InternetService_No                     7043 non-null   bool
#  13  OnlineSecurity_Yes                     7043 non-null   bool
#  14  OnlineBackup_Yes                       7043 non-null   bool
#  15  DeviceProtection_Yes                   7043 non-null   bool
#  16  TechSupport_Yes                        7043 non-null   bool
#  17  StreamingTV_Yes                        7043 non-null   bool
#  18  StreamingMovies_Yes                    7043 non-null   bool
#  19  Contract_One year                      7043 non-null   bool
#  20  Contract_Two year                      7043 non-null   bool
#  21  PaperlessBilling_Yes                   7043 non-null   bool
#  22  PaymentMethod_Credit card (automatic)  7043 non-null   bool
#  23  PaymentMethod_Electronic check         7043 non-null   bool
#  24  PaymentMethod_Mailed check             7043 non-null   bool
#  25  Churn_Yes                              7043 non-null   bool
#  26  HighSpender                            7043 non-null   int64
#  27  HighChurnRisk                          7043 non-null   int64
# dtypes: bool(20), category(1), float64(3), int64(4)
# memory usage: 529.9 KB
# Processed dataset saved to data/processed/
