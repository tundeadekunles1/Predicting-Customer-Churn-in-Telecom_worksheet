# %%
#1. Set up imports 
# # Step 02: Feature Engineering

from src.feature_engineering import engineer_features
import pandas as pd
#2.reload cleaned dataset from Step 01
# Reload cleaned dataset from Step 01
from src.data_preprocessing import load_data, clean_data

df = load_data("data/raw/raw data/Telco-Customer-Churn.csv")
df = clean_data(df)
#3. Apply Engineering  features
df = engineer_features(df)

# Inspect engineered features
df[['SeniorCitizen', 'tenure', 'tenure_group']].head()

#4. check feature engineeering result

df.info()

#5. Save engineered dataset for model training

df.to_csv("data/processed/telco_churn_processed.csv", index=False)
print("Processed dataset saved to data/processed/")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User\Predicting-Customer-Churn-in-Telecom\notebooks

# %%
cd ..

# %%
#1. Set up imports 
# # Step 02: Feature Engineering

from src.feature_engineering import engineer_features
import pandas as pd
#2.reload cleaned dataset from Step 01
# Reload cleaned dataset from Step 01
from src.data_preprocessing import load_data, clean_data

df = load_data("data/raw/raw data/Telco-Customer-Churn.csv")
df = clean_data(df)
#3. Apply Engineering  features
df = engineer_features(df)

# Inspect engineered features
df[['SeniorCitizen', 'tenure', 'tenure_group']].head()

#4. check feature engineeering result

df.info()

#5. Save engineered dataset for model training

df.to_csv("data/processed/telco_churn_processed.csv", index=False)
print("Processed dataset saved to data/processed/")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
#  21  tenure_group      7043 non-null   category
#  22  HighSpender       7043 non-null   int64
#  23  PaymentRisk       7043 non-null   int64
#  24  HighChurnRisk     7043 non-null   int64
# dtypes: category(1), float64(1), int64(5), object(18)
# memory usage: 1.3+ MB
# Processed dataset saved to data/processed/
